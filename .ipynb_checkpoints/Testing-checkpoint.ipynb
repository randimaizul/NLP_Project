# %%
def uji(list):
    import random
    print(random.choice(list))

# %%
# Out:
# 1

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
perpus = ['mm.png','ipb.png','jabar.png','perpus.png','smanbul.png']
index = uji([1, 2, 3,4,5]);
print(perpus[0])
img=mpimg.imread('img/mm.png')
imgplot = plt.imshow(img)
# Out:
# mm.png
